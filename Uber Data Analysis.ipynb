# %% [markdown]
# # UBER DATA ANALYSIS

# %%
import numpy as np 
import pandas as pd
import cufflinks as cf
import seaborn as sns
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot,plot

init_notebook_mode(connected=True)

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df=pd.read_csv(r"C:\Users\Ankit Dwivedi\Dataset\practice_dataset-main\uberdrive.csv")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
# last 10 Record

df.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Karachi      2.9  Errand/Supplies
# 1147           Karachi      4.6  Errand/Supplies
# 1148           Karachi      4.6          Meeting
# ...

# %%
# first 10 dataset

df.head(10)
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %%
# Show the dimension of the dataset

df.shape
# Out:
# (1156, 7)

# %%
# Show the size of the dataset
df.size
# Out:
# 8092

# %%
# Print the information about all the variables of the data set.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
# Check for missing values.


df.isnull().values.any()
# Out:
# True

# %%
# How many missing values are present?

df.isnull().values.sum()
# Out:
# 507

# %%
# Get the initial data (name it 'df') with dropping the NA values
df1=df.dropna()

# %%
df1.isnull().values.any()
# Out:
# False

# %%
# Get the summary of the original data (before dropping the 'na' values)

df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
# Check the information of the new dataframe

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %%
# Get the unique start destinations
df["START*"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
# What is the total number of unique start destinations?
len(df["START*"].unique())
# Out:
# 177

# %%
# What is the total number of unique start destinations

set(df["STOP*"])
# Out:
# {'Agnew',
#  'Alief',
#  'Almond',
#  'Apex',
#  'Arabi',
#  'Arlington',
#  'Arlington Park at Amberly',
#  'Arts District',
#  'Asheville',
#  'Banner Elk',
#  'Bay Farm Island',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Bryson City',
#  'Burtrose',
#  'Bywater',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Cedar Hill',
#  'Central',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'College Avenue',
#  'Colombo',
#  'Columbia Heights',
#  'Congress Ave District',
#  'Convention Center District',
#  'Cory',
#  'Covington',
#  'Coxville',
#  'Daytona Beach',
#  'Depot Historic District',
#  'Downtown',
#  'Durham',
#  'Eagle Rock',
#  'East Elmhurst',
#  'East Harlem',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elk Park',
#  'Emeryville',
#  'Farmington Woods',
#  'Faubourg Marigny',
#  'Financial District',
#  'Florence',
#  'Fort Pierce',
#  'French Quarter',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
#  'Gramercy-Flatiron',
# ...

# %%
len(set(df["STOP*"]))
# Out:
# 188

# %%
# Print all the Uber trips that has the starting point of San Francisco

df[df["START*"]=="San Francisco"]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %%
# #  What is the most popular starting point for the Uber drivers

df_start=pd.DataFrame(df1["START*"].value_counts())

df_start= df_start.reset_index()
df_start=df_start.rename(columns = {"index":"Start","START*":"Count"})

# %%
df_start.loc[df_start["Count"]==max(df_start["Count"])]
# Out:
#   Start  Count
# 0  Cary    161

# %%
# What is the most popular dropping point for the Uber drivers

df_stop= pd.DataFrame(df1["STOP*"].value_counts())
df_stop=df_stop.reset_index()
df_stop=df_stop.rename(columns={"index":"STOP","STOP*":"Count"})

df_stop[df_stop["Count"]==max(df_stop["Count"])]
# Out:
#    STOP  Count
# 0  Cary    155

# %%
# List the most frequent route taken by Uber drivers
df_group = pd.DataFrame(df1.groupby(["START*","STOP*"]).size())
df_group.rename(columns = {0:"count"},inplace = True)
df_group=df_group.sort_values(["count"],ascending=False)
df_group[df_group["count"]==max(df_group["count"])]
# Out:
#                     count
# START* STOP*
# Cary   Morrisville     52

# %%
#  Print all types of purposes for the trip in an array
print(np.array(df["PURPOSE*"].unique()))
df3=pd.DataFrame(df1["MILES*"].groupby(df1["PURPOSE*"]).sum())
df3.reset_index(inplace= True)
df3
# Out:
# ['Meal/Entertain' nan 'Errand/Supplies' 'Meeting' 'Customer Visit'
#  'Temporary Site' 'Between Offices' 'Charity ($)' 'Commute' 'Moving'
#  'Airport/Travel']
#           PURPOSE*  MILES*
# 0   Airport/Travel    16.5
# 1  Between Offices   197.0
# 2      Charity ($)    15.1
# 3          Commute   180.2
# 4   Customer Visit  2089.5
# 5  Errand/Supplies   508.0
# 6   Meal/Entertain   911.7
# 7          Meeting  2851.3
# 8           Moving    18.2
# 9   Temporary Site   523.7

# %%
# Plot a bar graph of Purposes vs Distance
df3.plot( kind='bar',x="PURPOSE*",y="MILES*")

# %%
sns.barplot(x=df3["PURPOSE*"],y=df3["MILES*"])

# %%
# Plot number of trips vs Category of trips.

# %%
df4= df["CATEGORY*"].value_counts()
df4=pd.DataFrame(df4)
df4=df4.reset_index()
df4=df4.rename(columns ={"index":"Category","CATEGORY*":"count"})
df4
# Out:
#    Category  count
# 0  Business   1078
# 1  Personal     77

# %%
sns.barplot(x=df4["Category"],y=df4["count"])

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
# What is proportion of trips that is Business and what is the proportion of trips that is Personal

df5= df.groupby(["CATEGORY*"]).sum()
bussiness=df5.iloc[0,0]/(df5.iloc[0,0]+df5.iloc[1,0])
personal=df5.iloc[1,0]/(df5.iloc[0,0]+df5.iloc[1,0])
print("bussiness",bussiness)
print("personal",personal)
# Out:
# bussiness 0.9411947856153777
# personal 0.05880521438462235
